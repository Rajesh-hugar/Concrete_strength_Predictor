# %%
import sqlite3
from sqlite3 import Error

# %%
con = sqlite3.connect('Concrete_strength.db')
con

# %%
#con.execute("SELECT * FROM Concrete ")
#head_rows = con.fetchmany()
remaining_rows = con.execute('SELECT * FROM Concrete')
print(remaining_rows)

# %%
remaining_rows.fetchall()
# Out:
# [('cement',
#   'blast_furnace_slag',
#   'fly_ash',
#   'water',
#   'superplasticizer',
#   'coarse_aggregate',
#   'fine_aggregate ',
#   'age',
#   'concrete_compressive_strength'),
#  (540.0, 0.0, 0.0, 162.0, 2.5, 1040.0, 676.0, 28, 79.99),
#  (540.0, 0.0, 0.0, 162.0, 2.5, 1055.0, 676.0, 28, 61.89),
#  (332.5, 142.5, 0.0, 228.0, 0.0, 932.0, 594.0, 270, 40.27),
#  (332.5, 142.5, 0.0, 228.0, 0.0, 932.0, 594.0, 365, 41.05),
#  (198.6, 132.4, 0.0, 192.0, 0.0, 978.4, 825.5, 360, 44.3),
#  (266.0, 114.0, 0.0, 228.0, 0.0, 932.0, 670.0, 90, 47.03),
#  (380.0, 95.0, 0.0, 228.0, 0.0, 932.0, 594.0, 365, 43.7),
#  (380.0, 95.0, 0.0, 228.0, 0.0, 932.0, 594.0, 28, 36.45),
#  (266.0, 114.0, 0.0, 228.0, 0.0, 932.0, 670.0, 28, 45.85),
#  (475.0, 0.0, 0.0, 228.0, 0.0, 932.0, 594.0, 28, 39.29),
#  (198.6, 132.4, 0.0, 192.0, 0.0, 978.4, 825.5, 90, 38.07),
#  (198.6, 132.4, 0.0, 192.0, 0.0, 978.4, 825.5, 28, 28.02),
#  (427.5, 47.5, 0.0, 228.0, 0.0, 932.0, 594.0, 270, 43.01),
# ...

# %%
import pandas as pd 
conn = sqlite3.connect('Concrete_strength.db')
df=pd.read_sql_query(con=conn,sql='SELECT * FROM Concrete')
#df.drop(labels=0,axis=0,inplace=True)
df
# Out:
#       cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0     cement  blast_furnace_slag  fly_ash  water  superplasticizer
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      540.0                 0.0      0.0  162.0               2.5
# 3      332.5               142.5      0.0  228.0               0.0
# 4      332.5               142.5      0.0  228.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1026   276.4               116.0     90.3  179.6               8.9
# 1027   322.2                 0.0    115.6  196.0              10.4
# 1028   148.5               139.4    108.6  192.7               6.1
# 1029   159.1               186.7      0.0  175.6              11.3
# 1030   260.9               100.5     78.3  200.6               8.6
#
#       coarse_aggregate   fine_aggregate  age  concrete_compressive_strength
# 0     coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# ...

# %%
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0  cement  blast_furnace_slag  fly_ash  water  superplasticizer
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   540.0                 0.0      0.0  162.0               2.5
# 3   332.5               142.5      0.0  228.0               0.0
# 4   332.5               142.5      0.0  228.0               0.0
#
#    coarse_aggregate   fine_aggregate  age  concrete_compressive_strength
# 0  coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 1            1040.0            676.0   28                          79.99
# 2            1055.0            676.0   28                          61.89
# 3             932.0            594.0  270                          40.27
# 4             932.0            594.0  365                          41.05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031 entries, 0 to 1030
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cement                         1031 non-null   object
#  1   blast_furnace_slag             1031 non-null   object
#  2   fly_ash                        1031 non-null   object
#  3   water                          1031 non-null   object
#  4   superplasticizer               1031 non-null   object
#  5   coarse_aggregate               1031 non-null   object
#  6   fine_aggregate                 1031 non-null   object
#  7   age                            1031 non-null   object
#  8   concrete_compressive_strength  1031 non-null   object
# dtypes: object(9)
# memory usage: 72.6+ KB

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn

# %%
create_connection('Concrete_strength.db')

# %%
def querry(db_name, query):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        conn =sqlite3.connect(db_name)
        c = conn.cursor()
        c.execute(query)
    except Error as e:
        print(e)

# %%
query='select * from Concrete'

# %%
querry('Concrete_strength.db',query)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 for i in querry:
#       2     print(i)
#
# TypeError: 'function' object is not iterable

# %%
con.close()

# %%
conn.close()

# %%
conn

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)


def main():
    database = r"C:\sqlite\db\pythonsqlite.db"

    sql_create_projects_table = """ CREATE TABLE IF NOT EXISTS projects (
                                        id integer PRIMARY KEY,
                                        name text NOT NULL,
                                        begin_date text,
                                        end_date text
                                    ); """

    sql_create_tasks_table = """CREATE TABLE IF NOT EXISTS tasks (
                                    id integer PRIMARY KEY,
                                    name text NOT NULL,
                                    priority integer,
                                    status_id integer NOT NULL,
                                    project_id integer NOT NULL,
                                    begin_date text NOT NULL,
                                    end_date text NOT NULL,
                                    FOREIGN KEY (project_id) REFERENCES projects (id)
                                );"""

    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_projects_table)

        # create tasks table
        create_table(conn, sql_create_tasks_table)
    else:
        print("Error! cannot create the database connection.")


if __name__ == '__main__':
    main()
